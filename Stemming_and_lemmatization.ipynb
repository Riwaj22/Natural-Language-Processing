# %%
import nltk

# %%
from nltk.stem import PorterStemmer

# %%
porter = PorterStemmer()

# %%
porter.stem('walking')
# Out:
# 'walk'

# %%
porter.stem('walked')
# Out:
# 'walk'

# %%
porter.stem('walks')
# Out:
# 'walk'

# %%
porter.stem('ran')
# Out:
# 'ran'

# %%
porter.stem('running')
# Out:
# 'run'

# %%
porter.stem('bosses')
# Out:
# 'boss'

# %%
porter.stem('replacement')
# Out:
# 'replac'

# %%
sentence = "Lemmatization is more sophisticated than Stemmation"

# %%
for token in sentence:
  print(porter.stem(token), end = '')
# Out:
# lemmatization is more sophisticated than stemmation

# %%
porter.stem('unnecessary')
# Out:
# 'unnecessari'

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.stem import WordNetLemmatizer

# %%
from nltk.corpus import wordnet

# %%
lemmatizer = WordNetLemmatizer()

# %%
lemmatizer.lemmatize("walking")
# Out:
# 'walking'

# %%
lemmatizer.lemmatize("walking", pos = wordnet.VERB)
# Out:
# 'walk'

# %%
lemmatizer.lemmatize("going", pos = wordnet.VERB)
# Out:
# 'go'

# %%
def get_wordnet_pos(treebank_tag):
  if treebank_tag.startswith('J'):
    return wordnet.ADJ
  elif treebank_tag.startswith('V'):
    return wordnet.VERB
  elif treebank_tag.startswith('N'):
    return wordnet.NOUN
  elif treebank_tag.startswith('R'):
    return wordnet.ADV

  else:
    return wordnet.NOUN

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
sentence = "Donald Trumph has a desired following".split()

# %%
sentence
# Out:
# ['Donald', 'Trumph', 'has', 'a', 'desired', 'following']

# %%
words_and_tags = nltk.pos_tag(sentence)
words_and_tags
# Out:
# [('Donald', 'NNP'),
#  ('Trumph', 'NNP'),
#  ('has', 'VBZ'),
#  ('a', 'DT'),
#  ('desired', 'VBN'),
#  ('following', 'NN')]

# %%
from inspect import get_annotations
for word, tag in words_and_tags:
  lemma = lemmatizer.lemmatize(word, pos = get_wordnet_pos(tag))
  print(lemma , end = " ")
# Out:
# Donald Trumph have a desire following

# %%
sentence = "The cat was following the bird as it flew by".split()

# %%
words_and_tags = nltk.pos_tag(sentence)
words_and_tags
# Out:
# [('The', 'DT'),
#  ('cat', 'NN'),
#  ('was', 'VBD'),
#  ('following', 'VBG'),
#  ('the', 'DT'),
#  ('bird', 'NN'),
#  ('as', 'IN'),
#  ('it', 'PRP'),
#  ('flew', 'VBD'),
#  ('by', 'IN')]

# %%
from inspect import get_annotations
for word, tag in words_and_tags:
  lemma = lemmatizer.lemmatize(word, pos = get_wordnet_pos(tag))
  print(lemma , end = " ")
# Out:
# The cat be follow the bird a it fly by
